# %% [markdown]
# # Python Data Types Categories
#
# ## Basic Types:
# - **`Int`**: Whole nums (1, 2, 3).
# - **`Float`**: Decimals (3.14, 2.5).
# - **`Complex`**: Real+Imag (1 + 2j).
# - **`Bool`**: True/False.
# - **`Str`**: Text ("hello").
#
# ## Container Types:
# - **`List`**: Ordered items.
#   ```python
#   [1, 2, 3]
#   ```
# - **`Tuple`**: Ordered, immutable.
#   ```python
#   (1, 2, 3)
#   ```
# - **`Set`**: Unordered, unique.
#   ```python
#   {1, 2, 3}
#   ```
# - **`Dict`**: Key-value pairs.
#   ```python
#   {'k1': 'v1', 'k2': 'v2'}
#   ```
#
# ## User-Defined Types:
# - **`Class`**: Obj blueprint.

# %% [markdown]
# ### int

# %%
# Numbers
print(4)

# Large Numbers
print(1e308)  # 1 * 10^308
print(1e309)  # 'inf' (exceeds float limit)
# Out:
# 4
# 1e+308
# inf

# %% [markdown]
# ### float

# %%
# Floating-Point Numbers
print(4.5)  # Standard

# Large Floating-Point Numbers
print(1.8e307)  # Large
print(1.8e308)  # Larger
print(1.9e308)  # Too large (inf)
# Out:
# 4.5
# 1.8e+307
# inf
# inf

# %% [markdown]
# ### bool

# %%
# Boolean Values
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# ### complex

# %%
# Complex Number
print(4 + 5j)
# Out:
# (4+5j)

# %% [markdown]
# ### str

# %%
# Strings with Different Quotation Styles
print('Kolkata',7,end='#')       # single quotes
print("Kolkata")       # double quotes
print('''Kolkata''')   # triple single quotes
print("""Kolkata""")   # triple double quotes
# Out:
# Kolkata 7#Kolkata
# Kolkata
# Kolkata

# %% [markdown]
# ### list

# %%
a=[1, 2, 3, "Arjun", True]

# %%
b=[6,7]

# %%
b+[2]
# Out:
# [6, 7, 2]

# %%
c=a+b

# %%
print(c)
# Out:
# [1, 2, 3, 'Arjun', True, 6, 7]

# %%
print(a)
# Out:
# [1, 2, 3, 'Arjun', True]

# %%
type(a)
# Out:
# list

# %%
# List
print([1, 2, 3, 4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### tuple

# %%
tup1=(1,2,3,"Arjun")
tup2=(2,4,7)

# %%
tup=tup1+tup2

# %%
print(tup)
# Out:
# (1, 2, 3, 'Arjun', 2, 4, 7)

# %%
tup1
# Out:
# (1, 2, 3, 'Arjun')

# %%
tup1+(12,44)
# Out:
# (1, 2, 3, 'Arjun', 12, 44)

# %%
type(tup1)
# Out:
# tuple

# %%
# Tuple
print((1, 2, 3, 4, 5))
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### set

# %%
a={1,1,1,1,2,3}
print(a)
# Out:
# {1, 2, 3}

# %%
type(a)
# Out:
# set

# %%
# Set
print({1, 2, 3, 4, 5})
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### dict

# %%
dict1={"veg":"tomato","weight":"1Kg", "price":50}
dict2={"veg":"Radish","weight":"1Kg", "price":30}

# %%
dict1
# Out:
# {'veg': 'tomato', 'weight': '1Kg', 'price': 50}

# %%
dict2
# Out:
# {'veg': 'Radish', 'weight': '1Kg', 'price': 30}

# %%
# Dictionary
print({"Name": "Saurabh", "Age": 22, "Gender": "Male"})
# Out:
# {'Name': 'Saurabh', 'Age': 22, 'Gender': 'Male'}
